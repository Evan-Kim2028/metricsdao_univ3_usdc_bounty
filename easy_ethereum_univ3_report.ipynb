# %% [markdown]
# # Easy Ethereum Uniswap V3 Bounty Report

# %%
from IPython.display import Image # used to load images from the charts folder

# %% [markdown]
# This report was created to submit to the [Metrics Dao Easy Ethereum Bounty](https://metricsdao.xyz/app/market/0x280b3b748Ccc42D5062CE59111fAd08594f51d9F/request/192).
#
# Initial Bounty Criteria:
# * Choose 1 pool on Uniswap V3 where one of the token pair is USDC.
# * Show the daily volume of transactions where USDC was swapped for the other token.
# * Show the daily volume of transactions where the token was swapped for USDC.
# * Show the aggregate daily total swap volume of your chosen pool.
# * Show the daily number of transactions that used this pool.

# %% [markdown]
# ### Introduction
#
# Rather than focus on a single Univ3 pool, this report focuses on a single Univ3 pair, USDC/WETH. There are 4 respective pools differentiated by their fee structure  5bps, 30bps, 100bps, and 150bps (0.05%, 0.3%, 1%, and 1.5%). The report will analyze the USDC/WETH pair across all 4 pools. Additionally, the report will also analyze the USDC/WETh Univ3 pair on Arbitrum to compare the token pair data across chains.

# %% [markdown]
# ### Pool Volume Chart Highlights:
# * 5bps pool has highest volume across Ethereum and Arbitrum
# * 30bps pool has second highest volume on Ethereum, but not on Arbitrum
# * 1bps pool has negligible volume consistent across Ethereum and Arbitrum
#
#
# The below chart shows pool volume between all the WETH/USDC pairs on both Arbitrum and Ethereum. It is interesting to see that the majority of pool volume on both chains comes from the USDC/WETH 5 bps pool. Additionally, the Ethereum 30bps pool has the secondmost volume, but clearly has a bigger share of volume on Ethereum than Arbitrum. It's also surprising that the WETH/USDC 1bps pool doesn't contain more swap volume. On surface level one would assume that a lower fee would create more volume.

# %%
Image(filename='charts/plot_pool_vol.png')

# %% [markdown]
# The below chart shows the transaction counts for the USDC/WETH pools on both Ethereum and Arbitrum. Now we start to see divergences in the data. The 1 bps pool on Arbitrum carries more swap transactions on arbitrum than the 3bps pool at a less overall volume. In contrast, the 1 bps pool has less swa ptransactions than the 3bps pool on Ethereum.

# %%
Image(filename='charts/plot_pool_count.png')

# %% [markdown]
# The next chart shows the quantile breakdown for transaction sizes between pools. At the 75th percentile, the Arbitrum 5 bps pool has a higher transaction size value than the 30bps pool. What's striking is that this is reversed for Ethereum. What isn't surprising overall is that larger.

# %%
Image(filename='charts/plot_transaction_quantiles.png')

# %% [markdown]
# The next ste of charts show the directional token volume between the pairs. This is perhaps the least interesting at face value due to the time slice and the granularity of data. If the time horizon was for a longer period of time such as 30 days this would capture a larger market volatility trend. Additionally, zooming into say a 1 hour time slice would show a more granular view of the data and tease out the intra-day market volatility between the pairs.

# %%
Image(filename='charts/plot_pool_directional_volume.png')

# %% [markdown]
# The below chart shows cross chain volume and transaction counts respectively. It is no surprise that Ethereum makes up the majority of the volume and transaction counts. However, it is interesting to note that Arbitrum has significantly higher transaction counts than Ethereum, which further validates the need for scaling solutions.

# %%
Image(filename='charts/plot_aggregate_pool_data.png')
